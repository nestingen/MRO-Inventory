# %%
#Amy Nestingen
#DSC 680 Project 1
#MRO Inventory Data Collection: Combine all MRO Inventory files and stage for Qlik Sense

# %%
#Show all output
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#imports
import os
import numpy as np
import pandas as pd

# %%
#Change Working Directory

os.chdir("\\Users\\Amy.Nestingen\\Desktop\\MRO Inventory\\GE1")
os.getcwd()
# Out:
# 'C:\\Users\\Amy.Nestingen\\Desktop\\MRO Inventory\\GE1'

# %%
#Read in GE1 files
cwd = os.path.abspath('\\Users\\Amy.Nestingen\\Desktop\\MRO Inventory\\GE1')
files = os.listdir(cwd)
files
# Out:
# ['SAP GE1 MRO Materials 20191127.xlsx',
#  'SAP GE1 MRO Materials 20191226.xlsx',
#  'SAP GE1 MRO Materials 20200130.xlsx',
#  'SAP GE1 MRO Materials 20200227.xlsx',
#  'SAP GE1 MRO Materials 20200326.xlsx',
#  'SAP GE1 MRO Materials 20200430.xlsx',
#  'SAP GE1 MRO Materials 20200528.xlsx',
#  'SAP GE1 MRO Materials 20200625.xlsx',
#  'SAP GE1 MRO Materials 20200730.xlsx',
#  'SAP GE1 MRO Materials 20200831.xlsx',
#  'SAP GE1 MRO Materials 20200930.xlsx',
#  'SAP GE1 MRO Materials 20201029.xlsx',
#  'SAP GE1 MRO Materials 20201130.xlsx',
#  'SAP GE1 MRO Materials 20201203.xlsx']

# %%
#Read in GE1 Files
ge1_1 = pd.read_excel('SAP GE1 MRO Materials 20191127.xlsx')
ge1_2 = pd.read_excel('SAP GE1 MRO Materials 20191226.xlsx')
ge1_3 = pd.read_excel('SAP GE1 MRO Materials 20200130.xlsx')
ge1_4 = pd.read_excel('SAP GE1 MRO Materials 20200227.xlsx')
ge1_5 = pd.read_excel('SAP GE1 MRO Materials 20200326.xlsx')
ge1_6 = pd.read_excel('SAP GE1 MRO Materials 20200430.xlsx')
ge1_7 = pd.read_excel('SAP GE1 MRO Materials 20200528.xlsx')
ge1_8 = pd.read_excel('SAP GE1 MRO Materials 20200625.xlsx')
ge1_9 = pd.read_excel('SAP GE1 MRO Materials 20200730.xlsx')
ge1_10 = pd.read_excel('SAP GE1 MRO Materials 20200831.xlsx')
ge1_11 = pd.read_excel('SAP GE1 MRO Materials 20200930.xlsx')
ge1_12 = pd.read_excel('SAP GE1 MRO Materials 20201029.xlsx')
ge1_13 = pd.read_excel('SAP GE1 MRO Materials 20201130.xlsx')
ge1_14 = pd.read_excel('SAP GE1 MRO Materials 20201203.xlsx')

# %%
#Change Working Directory

os.chdir("\\Users\\Amy.Nestingen\\Desktop\\MRO Inventory\\PRD")
os.getcwd()
# Out:
# 'C:\\Users\\Amy.Nestingen\\Desktop\\MRO Inventory\\PRD'

# %%
#Read in GE1 files
pcwd = os.path.abspath('\\Users\\Amy.Nestingen\\Desktop\\MRO Inventory\\PRD')
pfiles = os.listdir(pcwd)
pfiles
# Out:
# ['data.csv',
#  'SAP PRD MRO Materials with Capital 20191127.xlsx',
#  'SAP PRD MRO Materials with Capital 20191226.xlsx',
#  'SAP PRD MRO Materials with Capital 20200130.xlsx',
#  'SAP PRD MRO Materials with Capital 20200227.xlsx',
#  'SAP PRD MRO Materials with Capital 20200326.xlsx',
#  'SAP PRD MRO Materials with Capital 20200430.xlsx',
#  'SAP PRD MRO Materials with Capital 20200528.xlsx',
#  'SAP PRD MRO Materials with Capital 20200625.xlsx',
#  'SAP PRD MRO Materials with Capital 20200730.xlsx',
#  'SAP PRD MRO Materials with Capital 20200831.xlsx',
#  'SAP PRD MRO Materials with Capital 20200930.xlsx',
#  'SAP PRD MRO Materials with Capital 20201029.xlsx',
#  'SAP PRD MRO Materials with Capital 20201130.XLSX',
#  'SAP PRD MRO Materials with Capital 20201203.xlsx']

# %%
#Read in PRD Data
prd_1 = pd.read_excel('SAP PRD MRO Materials with Capital 20191127.xlsx')
prd_2 = pd.read_excel('SAP PRD MRO Materials with Capital 20191226.xlsx')
prd_3 = pd.read_excel('SAP PRD MRO Materials with Capital 20200130.xlsx')
prd_4 = pd.read_excel('SAP PRD MRO Materials with Capital 20200227.xlsx')
prd_5 = pd.read_excel('SAP PRD MRO Materials with Capital 20200326.xlsx')
prd_6 = pd.read_excel('SAP PRD MRO Materials with Capital 20200430.xlsx')
prd_7 = pd.read_excel('SAP PRD MRO Materials with Capital 20200528.xlsx')
prd_8 = pd.read_excel('SAP PRD MRO Materials with Capital 20200625.xlsx')
prd_9 = pd.read_excel('SAP PRD MRO Materials with Capital 20200730.xlsx')
prd_10 = pd.read_excel('SAP PRD MRO Materials with Capital 20200831.xlsx')
prd_11 = pd.read_excel('SAP PRD MRO Materials with Capital 20200930.xlsx')
prd_12 = pd.read_excel('SAP PRD MRO Materials with Capital 20201029.xlsx')
prd_13 = pd.read_excel('SAP PRD MRO Materials with Capital 20201130.XLSX')
prd_14 = pd.read_excel('SAP PRD MRO Materials with Capital 20201203.xlsx')

# %%
#Concat Dataframes
df = pd.concat([ge1_1,ge1_2,ge1_3,ge1_4,ge1_5,ge1_6,ge1_7,ge1_8,ge1_9,ge1_10,ge1_11,ge1_12,ge1_13,ge1_14,
               prd_1,prd_2,prd_3,prd_4,prd_5,prd_6,prd_7,prd_8,prd_9,prd_10,prd_11,prd_12,prd_13,prd_14])

df.to_csv('data.csv')

df.head(10)
df.tail(10)
# Out:
#         Date    Material                      Material Description   Plnt  \
# 0 2019-11-27   1471038.0         REDUCER, SPEED TIMBER 576-000-028  241.0
# 1 2019-11-27  43271622.0             O-RING, RUBBER SPXFLOW 015798  660.0
# 2 2019-11-27  43271620.0          DIAPHRAGM, RUBBER SPXFLOW 137282  660.0
# 3 2019-11-27  43271621.0          DIAPHRAGM, RUBBER SPXFLOW 195964  660.0
# 4 2019-11-27   1328049.0     ROD SEAL, SOLID RUBBER SPXFLOW 364745  660.0
# 5 2019-11-27   1181274.0  TENSIONER, COMPLTE CONSULTE 1001-0030-01  740.0
# 6 2019-11-27   1019101.0      PULLER, IDLER CONSULTEX 1001-0031-01  740.0
# 7 2019-11-27   1019103.0  ROTOR, D-COMPLETE CONSULTEX 1001-0032-01  740.0
# 8 2019-11-27   1019102.0      BELT, DRIVE CONSULTEX  1001-00330-30  740.0
# 9 2019-11-27   1122893.0    HOUSING, FILTER CONSULTEX 4000-0072-01  740.0
#
#   SLoc      Bin MRPC Unrestricted BUn Prc  ...  MRP  Pr. Mfr Matl group Type  \
# ...
